# %%
import pandas as pd

df= pd.read_csv('./iplauction2023.csv')

df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df["basePrice"]=df['base price (in lacs)']

# %%
df['basePrice']
# Out:
# 0        NaN
# 1       20.0
# 2       75.0
# 3      150.0
# 4      100.0
#        ...
# 304      NaN
# 305      NaN
# 306      NaN
# 307      NaN
# 308      NaN
# Name: basePrice, Length: 309, dtype: float64

# %%
df['finalPrice']=df['final price (in lacs)']

# %%
df['playerStyle']=df['player style']

# %%
df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status  basePrice  finalPrice  \
# ...

# %%
# List of columns to be dropped
columns_to_drop = ['base price (in lacs)', 'player style', 'final price (in lacs)']

# Drop specified columns
df = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#                 name   nationality franchise    status  basePrice  finalPrice  \
# 0       Harshit Rana         India       KKR  RETAINED        NaN        20.0
# 1          Ekant Sen         India       NaN    UNSOLD       20.0         NaN
# 2      Wayne Parnell  South Africa       NaN    UNSOLD       75.0         NaN
# 3    Shakib Al Hasan    Bangladesh       KKR      SOLD      150.0       150.0
# 4           Joe Root       England        RR      SOLD      100.0       100.0
# ..               ...           ...       ...       ...        ...         ...
# 304         MS Dhoni         India       CSK  RETAINED        NaN      1200.0
# 305        Moeen Ali       England       CSK  RETAINED        NaN       800.0
# 306  Ruturaj Gaikwad         India       CSK  RETAINED        NaN       600.0
# 307     Rishabh Pant         India        DC  RETAINED        NaN      1600.0
# 308       Axar Patel         India        DC  RETAINED        NaN       900.0
#
#     playerStyle
# ...

# %%
# Convert DataFrame to JSON
json_data = df.to_json(orient='records')

# Save JSON data to a file named 'output.json'
with open('iplauction.json', 'w') as json_file:
    json_file.write(json_data)

# Print or use the JSON data as needed
print(json_data)
# Out:
# [{"name":"Harshit Rana","nationality":"India","franchise":"KKR","status":"RETAINED","basePrice":null,"finalPrice":20.0,"playerStyle":"Bowler"},{"name":"Ekant Sen","nationality":"India","franchise":null,"status":"UNSOLD","basePrice":20.0,"finalPrice":null,"playerStyle":"Batter"},{"name":"Wayne Parnell","nationality":"South Africa","franchise":null,"status":"UNSOLD","basePrice":75.0,"finalPrice":null,"playerStyle":"Allrounder"},{"name":"Shakib Al Hasan","nationality":"Bangladesh","franchise":"KKR","status":"SOLD","basePrice":150.0,"finalPrice":150.0,"playerStyle":"Allrounder"},{"name":"Joe Root","nationality":"England","franchise":"RR","status":"SOLD","basePrice":100.0,"finalPrice":100.0,"playerStyle":"Batter"},{"name":"Abdul Basith","nationality":"India","franchise":"RR","status":"SOLD","basePrice":20.0,"finalPrice":20.0,"playerStyle":"Allrounder"},{"name":"Prashant Chopra","nationality":"India","franchise":null,"status":"UNSOLD","basePrice":20.0,"finalPrice":null,"playerStyle":"Allro
# ...
